# %%
import pandas as pd
date = pd.read_csv('data.csv')

date.describe()
# Out:
#               Time    REAL_DATA    TELE_DATA
# count  5473.000000  5473.000000  5473.000000
# mean   2736.000000   220.382971   217.418052
# std    1580.063343     2.302161     2.135209
# min       0.000000   213.000000   211.000000
# 25%    1368.000000   218.000000   216.000000
# 50%    2736.000000   221.000000   218.000000
# 75%    4104.000000   222.000000   219.000000
# max    5472.000000   223.000000   220.000000

# %%
date_masurate = date['REAL_DATA']
date_masurate.plot.line()
plt.show()

# %%
def rolling_window(func, window_size, series):
    output = ['NA']*window_size
    for i in range(window_size,len(series)):
        output.append(func(series[i-window_size:i]))
    return output

# %%
date['300_step_ma1']=rolling_window(lambda x : sum(x)/len(x), 300, date['REAL_DATA'].tolist())

# %%
from matplotlib import pyplot as plt

date = date[date['300_step_ma'] != 'NA']

moving_average = date['300_step_ma'].diff()
moving_average.plot.line()
plt.show()

# %%
from quantecon import periodogram, ARMA
x, y_netezit = periodogram(date['300_step_ma'], window='hamming', window_len=300)

fig, ax = plt.subplots(1, 1, figsize=(10,12))

ax.semilogy(x, y_netezit, 'k-', lw=2, alpha=0.75,
        label='standard smoothed periodogram')

plt.show()
# Out:
# Window length reset to 301

# %%
n = len(moving_average.tolist())                          # Data size
ϕ, θ = 0.5, (0, -0.8)           # AR and MA parameters
lp = ARMA(ϕ, θ)
X = date['REAL_DATA']

fig, ax = plt.subplots()
x, y = periodogram(X,window='hamming', window_len=300)
ax.plot(x, y, 'b-', lw=2, alpha=0.5, label='periodogram')
x_sd, y_sd = lp.spectral_density(two_pi=False, res=120)
ax.plot(x_sd, y_sd, 'r-', lw=2, alpha=0.8, label='spectral density')
ax.legend()
plt.show()
# Out:
# Window length reset to 301
