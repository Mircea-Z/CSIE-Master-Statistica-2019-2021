# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from quantecon import ARMA, periodogram, ar_periodogram
import pandas as pd

# %%
data = pd.read_csv('data.csv')
data.describe()
# Out:
#                Time     REAL_DATA     TELE_DATA
# count  77913.000000  77913.000000  77913.000000
# mean   38956.000000    198.879096    196.060670
# std    22491.690099     16.557785     16.528434
# min        0.000000    165.000000    162.000000
# 25%    19478.000000    185.000000    182.000000
# 50%    38956.000000    199.000000    196.000000
# 75%    58434.000000    214.000000    211.000000
# max    77912.000000    227.000000    225.000000

# %%
n = data.count                          # Data size
ϕ, θ = 0.5, (0, -0.8)           # AR and MA parameters
lp = ARMA(ϕ, θ)
X = data['REAL_DATA']

fig, ax = plt.subplots()
x, y = periodogram(X)
ax.plot(x, y, 'b-', lw=2, alpha=0.5, label='periodogram')
x_sd, y_sd = lp.spectral_density(two_pi=False, res=120)
ax.plot(x_sd, y_sd, 'r-', lw=2, alpha=0.8, label='spectral density')
ax.legend()
plt.show()

# %%
# Out:
# 15495267

# %%
moving_average = [sum(data['REAL_DATA'].to_list()[i-10:i])/10 for i in range(10,data.count()[0])]
print(moving_average)
moving_average_file = open('moving_average.csv','w')

[moving_average_file.write(str(item)+'\n') for item in moving_average]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-0c4c5f3b6511> in <module>
# ----> 1 moving_average = [sum(data['REAL_DATA'].to_list()[i-10:i])/10 for i in range(10,data.count())]
#       2 print(moving_average)
#       3 moving_average_file = open('moving_average.csv','w')
#       4
#       5 [moving_average_file.write(str(item)+'\n') for item in moving_average]
#
# TypeError: 'Series' object cannot be interpreted as an integer
